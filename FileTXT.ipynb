// %% [markdown]
// # Работа с текстовыми файлами

// %%
using System.IO;

const string TEMP_DIR = "temp";

if (! Directory.Exists(TEMP_DIR))
    Directory.CreateDirectory(TEMP_DIR);

// %%
Path.Combine(TEMP_DIR, "text.txt");

// %%
var fileName = Path.Combine(TEMP_DIR, "temp_TXT.txt");
Console.WriteLine(fileName);


try
{
    using (var f = new StreamWriter(fileName))
    {
        f.WriteLine("sdfsdf");
    }
}
catch (System.Exception)
{
    
    throw;
}
File.WriteAllText(filename, "sdfsdf\nsdf\nsdf");
// Out:
// (17,19): error CS0103: Имя "filename" не существует в текущем контексте.
// Error: compilation error

// %%
{
    using var f = new StreamWriter(fileName, append:true);
    f.WriteLine("sdfsdf");
    f.WriteLine("hdsd");
}
// Out:
// (1,33): error CS0103: Имя "filename" не существует в текущем контексте.
//
// (4,12): error CS0029: Не удается неявно преобразовать тип "string" в "bool".
// Error: compilation error

// %%
{using (var f = new StreamReader(fileName))
{
    string line;
    while ()
    {
        System.Console.WriteLine(line);
    }
}
}
// Out:
// (4,12): error CS0029: Не удается неявно преобразовать тип "string" в "bool".
// Error: compilation error

// %%
File.WriteAllText(fileName, "sdfsdf\nsdf\nsdf");

File.AppendAllText(fileName, DateTime.Now.ToString());

string text = File.ReadAllText(fileName);
System.Console.WriteLine(text);
// Out:
// sdfsdf
// sdf
// sdf22.04.2026 10:28:09

// %%
using System.Text;

File.WriteAllText(fileName, "ываы", Encoding.ASCII);
